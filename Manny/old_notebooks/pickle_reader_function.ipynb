# %%
import os
import csv
import pandas as pd
from acquire import *
import re

# %% [markdown]
# # Robot Pickles!

# %%
def read_pickles_in_directory(directory_path):
    robot_dict = {}
    regex_pattern = r'(.+)_((match_history)|(stats))\.pkl'

    for filename in os.listdir(directory_path):
        match = re.match(regex_pattern, filename)
        if match:
            robot_name = match.group(1)
            table_type = match.group(2)
            key = robot_name

            with open(os.path.join(directory_path, filename), 'rb') as f:
                df = pd.read_pickle(f)
                if not df.empty:
                    if key in robot_dict:
                        robot_dict[key][table_type] = df
                    else:
                        robot_dict[key] = {table_type: df}

    return robot_dict

# %% [markdown]
# # Read All Pickle Files

# %%
robot_dict = read_pickles_in_directory("pickle-files")

# %% [markdown]
# # Verify Pickle Files

# %% [markdown]
# #### Robot Links JSON

# %%
# loading the JSON file with all season & robot links
robot_links_dict = load_from_json("all_season_robot_links.json")

# %%
total_length = 0
for value in robot_links_dict.values():
    if isinstance(value, list):
        total_length += len(value)

print(f"Total number of items in all lists: {total_length}")
# Out:
# Total number of items in all lists: 394

# %%
# Set the directory where the files are located
directory = "pickle-files"

# Initialize sets to store robot names from match history and stats tables
match_history_robots = set()
stats_robots = set()

# Iterate over files in the directory
for filename in os.listdir(directory):
    # Check if the file is a match history table
    if filename.endswith("_match_history.pkl"):
        # Extract the robot name from the filename
        robot_name = filename[:-len("_match_history.pkl")]
        # Add the robot name to the set of match history robots
        match_history_robots.add(robot_name)
    # Check if the file is a stats table
    elif filename.endswith("_stats.pkl"):
        # Extract the robot name from the filename
        robot_name = filename[:-len("_stats.pkl")]
        # Add the robot name to the set of stats robots
        stats_robots.add(robot_name)

# Get the set of unique robot names from both tables
unique_robots = match_history_robots.union(stats_robots)

# Initialize lists to store missing robot names
missing_match_history = []
missing_stats = []
missing_both = []
missing_from_directory = []

# Check each robot name in the unique set
for robot_name in unique_robots:
    # Check if the robot name is in the robot_links_dict
    robot_name_in_links = False
    for links_list in robot_links_dict.values():
        for link in links_list:
            if robot_name in link:
                robot_name_in_links = True
                break
        if robot_name_in_links:
            break
    if not robot_name_in_links:
        missing_from_directory.append(robot_name)
    else:
        # Check if the robot has a match history table
        if robot_name not in match_history_robots:
            missing_match_history.append(robot_name)
        # Check if the robot has a stats table
        if robot_name not in stats_robots:
            missing_stats.append(robot_name)
        # Check if the robot has both tables
        if robot_name not in match_history_robots or robot_name not in stats_robots:
            missing_both.append(robot_name)

# Check each robot name in the robot_links_dict
for key in robot_links_dict.keys():
    for robot_link in robot_links_dict[key]:
        robot_name = robot_link.split("/")[-2]
        # Check if the robot name is in the set of unique robots
        if robot_name not in unique_robots:
            missing_from_directory.append(robot_name)

# Print the results
print("Total unique robots in directory:", len(unique_robots))
for robot_name in missing_match_history:
    print(f"{robot_name} missing match history table")
for robot_name in missing_stats:
    print(f"{robot_name} missing stats table")
for robot_name in missing_both:
    print(f"{robot_name} missing match history and/or stats table")

print("Missing these robots in directory:")
print("="*30)

missing_robot_links_list = []
for robot_name in missing_from_directory:
    # Check each robot link in the robot_links_dict
    for key in robot_links_dict.keys():
        for robot_link in robot_links_dict[key]:
            # Extract the robot name from the link
            link_robot_name = robot_link.split("/")[-2]
            # Check if the link robot name matches the missing robot name
            if link_robot_name == robot_name:
                # Print the missing robot name and link
                print(f"{robot_name}\n{robot_link}")
                missing_robot_links_list.append(robot_link)
                print("="*30)
                break
# Out:
# Total unique robots in directory: 316
# Missing these robots in directory:
# ==============================
# jager-2021
# https://battlebots.com/robot/jager-2021/
# ==============================
# smeeeeeeeeeeeeeeeeee-2021
# https://battlebots.com/robot/smeeeeeeeeeeeeeeeeee-2021/
# ==============================
# electric-ray-2019
# https://battlebots.com/robot/electric-ray-2019/
# ==============================
# bombshell-2
# https://battlebots.com/robot/bombshell-2/
# ==============================
# brutus-2018
# https://battlebots.com/robot/brutus-2018/
# ==============================
# chomp-s3
# https://battlebots.com/robot/chomp-s3/
# ==============================
# double-dutch
# https://battlebots.com/robot/double-dutch/
# ==============================
# duck
# https://battlebots.com/robot/duck/
# ==============================
# free-shipping-2018
# https://battlebots.com/robot/free-shipping-2018/
# ==============================
# gemini-2
# https://battlebots.com/robot/gemini-2/
# ==============================
# huge-s3
# https://battlebots.com/robot/huge-s3/
# ==============================
# hypothermia-s3
# https://battlebots.com/robot/hypothermia-s3/
# ==============================
# kraken-s3
# https://battlebots.com/robot/kraken-s3/
# ==============================
# lucky
# https://battlebots.com/robot/lucky/
# ==============================
# minotaur-s3
# https://battlebots.com/robot/minotaur-s3/
# ==============================
# monsoon-s3
# https://battlebots.com/robot/monsoon-s3/
# ==============================
# parallax-s3
# https://battlebots.com/robot/parallax-s3/
# ==============================
# predator-s3
# https://battlebots.com/robot/predator-s3/
# ==============================
# red-devil-2018
# https://battlebots.com/robot/red-devil-2018/
# ==============================
# sawblaze-s3
# https://battlebots.com/robot/sawblaze-s3/
# ==============================
# skorpios-2
# https://battlebots.com/robot/skorpios-2/
# ==============================
# subzero-2018
# https://battlebots.com/robot/subzero-2018/
# ==============================
# the-four-horsemen-s3
# https://battlebots.com/robot/the-four-horsemen-s3/
# ==============================
# ultimo-destructo-2018
# https://battlebots.com/robot/ultimo-destructo-2018/
# ==============================
# vanquish-s3
# https://battlebots.com/robot/vanquish-s3/
# ==============================
# war-hawk
# https://battlebots.com/robot/war-hawk/
# ==============================
# warhead-3
# https://battlebots.com/robot/warhead-3/
# ==============================
# whiplash-s3
# https://battlebots.com/robot/whiplash-s3/
# ==============================
# yeti-2
# https://battlebots.com/robot/yeti-2/
# ==============================
# ambush-s2
# https://battlebots.com/robot/ambush-s2/
# ==============================
# bad-kitty
# https://battlebots.com/robot/bad-kitty/
# ==============================
# beta-2
# https://battlebots.com/robot/beta-2/
# ==============================
# black-ice
# https://battlebots.com/robot/black-ice/
# ==============================
# bombshell
# https://battlebots.com/robot/bombshell/
# ==============================
# brutus
# https://battlebots.com/robot/brutus/
# ==============================
# captain-shrederator-2
# https://battlebots.com/robot/captain-shrederator-2/
# ==============================
# chromefly-s2
# https://battlebots.com/robot/chromefly-s2/
# ==============================
# complete-control-2
# https://battlebots.com/robot/complete-control-2/
# ==============================
# death-roll-s2
# https://battlebots.com/robot/death-roll-s2/
# ==============================
# the-dentist
# https://battlebots.com/robot/the-dentist/
# ==============================
# the-disk-o-inferno
# https://battlebots.com/robot/the-disk-o-inferno/
# ==============================
# gemini
# https://battlebots.com/robot/gemini/
# ==============================
# hellachopper
# https://battlebots.com/robot/hellachopper/
# ==============================
# icewave-2
# https://battlebots.com/robot/icewave-2/
# ==============================
# lock-jaw-2
# https://battlebots.com/robot/lock-jaw-2/
# ==============================
# lycan
# https://battlebots.com/robot/lycan/
# ==============================
# minotaur-s2
# https://battlebots.com/robot/minotaur-s2/
# ==============================
# mohawk-s2
# https://battlebots.com/robot/mohawk-s2/
# ==============================
# obwalden-overlord-s2
# https://battlebots.com/robot/obwalden-overlord-s2/
# ==============================
# overhaul-2
# https://battlebots.com/robot/overhaul-2/
# ==============================
# poison-arrow-s2
# https://battlebots.com/robot/poison-arrow-s2/
# ==============================
# preying-mantis
# https://battlebots.com/robot/preying-mantis/
# ==============================
# razorback-2
# https://battlebots.com/robot/razorback-2/
# ==============================
# the-ringmaster
# https://battlebots.com/robot/the-ringmaster/
# ==============================
# road-rash
# https://battlebots.com/robot/road-rash/
# ==============================
# rotator
# https://battlebots.com/robot/rotator/
# ==============================
# skorpios
# https://battlebots.com/robot/skorpios/
# ==============================
# splatter-2
# https://battlebots.com/robot/splatter-2/
# ==============================
# subzero
# https://battlebots.com/robot/subzero/
# ==============================
# ultraviolent
# https://battlebots.com/robot/ultraviolent/
# ==============================
# warhead-2
# https://battlebots.com/robot/warhead-2/
# ==============================
# witch-doctor-2
# https://battlebots.com/robot/witch-doctor-2/
# ==============================
# yeti
# https://battlebots.com/robot/yeti/
# ==============================
# bite-force
# https://battlebots.com/robot/bite-force/
# ==============================
# bull-dog
# https://battlebots.com/robot/bull-dog/
# ==============================
# chomp
# https://battlebots.com/robot/chomp/
# ==============================
# chronic
# https://battlebots.com/robot/chronic/
# ==============================
# complete-control
# https://battlebots.com/robot/complete-control/
# ==============================
# ghost-raptor
# https://battlebots.com/robot/ghost-raptor/
# ==============================
# icewave
# https://battlebots.com/robot/icewave/
# ==============================
# mohawk
# https://battlebots.com/robot/mohawk/
# ==============================
# overdrive
# https://battlebots.com/robot/overdrive/
# ==============================
# plan-x
# https://battlebots.com/robot/plan-x/
# ==============================
# razorback
# https://battlebots.com/robot/razorback/
# ==============================
# stinger
# https://battlebots.com/robot/stinger/
# ==============================
# tombstone
# https://battlebots.com/robot/tombstone/
# ==============================
# warrior-clan
# https://battlebots.com/robot/warrior-clan/
# ==============================
# wrecks
# https://battlebots.com/robot/wrecks/
# ==============================

# %%
# Set the output CSV file name
output_file = "missing_robot_links.csv"

# Write the missing robot links to the CSV file
with open(output_file, "w", newline="") as csvfile:
    writer = csv.writer(csvfile)
    for link in missing_robot_links_list:
        writer.writerow([link])

# %% [markdown]
# # Dictionary of DataFrames!

# %% [markdown]
# #### Keys = Robot

# %%
for i in robot_dict.keys():
    print(i)
# Out:
# tombstone-2021
# bronco-2020
# rampage-2020
# doomba-wcvii
# free-shipping-2021
# rotator-2019
# nightmare-2
# deadlift-2020
# extinguisher-2019
# lock-jaw-wcvii
# mammoth-2019
# black-dragon-wcvii
# uppercut-2020
# lucky-2019
# madcatter-2021
# jackpot-2021
# beta-2020
# railgun-max
# nightmare
# deathroll-2019
# rotator-2020
# tantrum
# shatter-2020
# bombshell-2019
# valkyrie-2019
# creepy-crawlies
# icewave-2021
# valkyrie-wcvii
# radioactive
# hypershock-2020
# cobalt-wcvii
# triple-crown-2021
# starchild-wcvii
# whiplash-2020
# bale-spear-s3
# monsoon-2019
# hydra-wcvii
# tombstone-2
# black-dragon-2020
# dragon-slayer-2021
# copperhead-2021
# splatter
# foxtrot-2019
# overhaul-wcvii
# cobalt-2021
# perfect-phoenix-2021
# skorpios-2019
# bloodsport-2020
# hijinx-wcvii
# battlesaw-2019
# gigabyte-2020
# tantrum-wcvii
# ghost-raptor-2021
# bite-force-2
# copperhead-2019
# sow
# sawblaze
# photon-storm-s2
# kingpin-2019
# terrortops-wcvii
# overhaul
# daisy-cutter-2019
# madcatter-wcvii
# mammoth-2021
# ultimo-destructo
# tombstone-2019
# double-tap-wcvii
# perfect-phoenix-2020
# gruff-2021
# petunia
# stinger-2
# ominous-wcvii
# end-game-wcvii
# rusty-2020
# valkyrie-2021
# breaker-box-2019
# 25345
# quantum-2019
# gigabyte
# lock-jaw-2018
# blip-wcvii
# captain-shrederator-2021
# skorpios-wcvii
# uppercut-2021
# sawblaze-2019
# mohawk-s3
# captain-shrederator
# blacksmith-2019
# jackpot-2020
# madcatter-2020
# shatter-2021
# deep-six-2021
# grabot-2020
# lucky-2021
# jasper-2019
# hypershock-2021
# tantrum-2020
# fusion-wcvii
# emulsifier-wcvii
# icewave-2020
# axe-backwards-2019
# pain-train-2020
# subzero-2019
# sporkinok-2020
# gemini-2019
# whiplash-2021
# sweet-revenge
# banshee-wcvii
# captain-shredderator-wcvii
# warrior-clan-2
# black-dragon-2021
# bloodsport-2021
# nelly-the-ellybot-2019
# texas-twister-2019
# subzero-2021
# bite-force-2019
# huge-wcvii
# kraken-2019
# p1-2020
# witch-doctor-2018
# warrior-dragon-2018
# hijinx-2020
# black-dragon-2019
# defender-2021
# duck-2021
# war-ez-2020
# copperhead-wcvii
# hydra-2019
# end-game-2020
# sharko-2020
# icewave-3
# blade-2021
# basilisk-2
# lock-jaw-2020
# captain-shrederator-2019
# rotato%d1%8f-s3
# gruff-2020
# sharkoprion-2019
# bucktooth-burl-s2
# malice-2020
# deep-six-2019
# gamma-9-2020
# invader
# beta
# claw-viper-wcvii
# sawblaze-2021
# blacksmith-2021
# deathroll-wcvii
# tombstone-2018
# aegis-2020
# jackpot-wcvii
# axolotl-2020
# rotator-2021
# whiplash-wcvii
# rampage-2021
# tombstone-2020
# mecha-rampage
# reality
# blacksmith-2018
# yeti-2021
# deadlift-2021
# switchback-2021
# red-devil-s2
# hypershock-wcvii
# rotator-wcvii
# son-of-whyachi-sow-2020
# gemini-2020
# war-hawk-2019
# copperhead-2020
# nightmare-2019
# captain-shrederator-3
# gigabyte-2019
# gruff-wcvii
# ribbot-wcvii
# chomp-2020
# chronos-2020
# lock-jaw-2021
# glitch-wcvii
# son-of-whyachi-2019
# deviled-egg-2018
# overhaul-2021
# overdrive-2
# shellshock-2019
# cobalt-s2
# end-game-2019
# ribbot-2020
# counter-revolution
# minotaur-wcvii
# bronco
# gigabyte-2021
# quantum-wcvii
# chomp-2
# ghost-raptor-2020
# lock-jaw
# p1-2021
# rusty-2021
# valkyrie-2020
# mammoth-2020
# yeti-2019
# ragnarok-2019
# basilisk
# claw-viper-2020
# bronco-2019
# huge-2019
# blip-2021
# kraken-wcvii
# subzero-2020
# captain-shrederator-2020
# lock-jaw-2019
# tantrum-2021
# double-jeopardy-2021
# valkyrie-s3
# hypershock-2
# marvin-2019
# p1-2019
# wrecks-2
# madcatter-2019
# pain-train-2021
# hijinx-2021
# son-of-whyachi-2018
# beta-wcvii
# minotaur-2021
# end-game
# end-game-2021
# ribbot-2021
# blacksmith
# bite-force-2018
# horizon-wcvii
# petunia-2019
# tantrum-2019
# atom94-2020
# slammo-wcvii
# sawblaze-2020
# monsoon-wcvii
# free-shipping-2019
# malice-wcvii
# claw-viper-2021
# gigabyte-wcvii
# black-widow-2020
# sharkoprion-2018
# malice-2021
# bloodsport-wcvii
# chronos-2019
# shreddit-bro-wcvii
# switchback-wcvii
# double-jeopardy-2019
# tracer-2020
# free-shipping-wcvii
# battle-royale-with-cheese-s3
# sidewinder-2019
# falcon-2019
# slammow-2020
# huge-2020
# mammoth-wcvii
# big-dill-2020
# hydra-2021
# fusion-2020
# gamma-9-s3
# axe-backwards-2020
# witch-doctor-2020
# triton-wcvii
# ribbot-2019
# sawblaze-wcvii
# whiplash-2019
# ripperoni-wcvii
# overhaul-2018
# minotaur-2019
# double-jeopardy-2018
# ghost-raptor-2
# hypershock
# the-four-horsemen-2019
# kraken-2021
# bloodsport-2019
# skorpios-2020
# hypershock-2018
# witch-doctor
# huge-2021
# retrograde-2021
# bronco-3
# mega-tento
# smeeeeeeeeeeeeeeeeee-2020
# rainbow-2019
# doom-wcvii
# lucky-wcvii
# bale-spear-2020
# riptide-2021
# duck-2019
# wanhoo-2019
# shatter-2019
# glitch-2021
# hypershock-2019
# warhead
# bronco-2
# uppercut-2019
# escape-velocity
# big-dill-2021
# extinguisher-2020
# cobalt-2019
# hydra-2020
# big-dill-wcvii
# moebius-s2
# dragon-king-wcvii
# shatter-wcvii
# fusion-2021
# slap-box-2020
# axe-backwards-s3
# lucky-s2
# rusty-jr-wcvii
# witch-doctor-2021
# gruff-2019
# slammo-2021
# kraken-2020
# pardon-my-french-2021
# skorpios-2021
# witch-doctor-wcvii
# riptide-wcvii

# %% [markdown]
# #### Nested Keys = DataFrames of Tables

# %%
robot_dict['rotator-2019'].keys()
# Out:
# dict_keys(['match_history', 'stats'])

# %% [markdown]
# # DataFrame # 1

# %%
robot_dict['rotator-2019']['match_history']
# Out:
#    Season                 Round                                     Matchup  \
# 0   WCVII           Episode 703                            Rotator vs Hydra
# 1   WCVII           Episode 706                          Rotator vs Jackpot
# 2   WCVII           Episode 711                       Rotator vs Bloodsport
# 3   WCVII           Episode 713                           Rotator vs Fusion
# 4    2021           Episode 602                           Kraken vs Rotator
# 5    2021           Episode 606                     Rotator vs Black Dragon
# 6    2021           Episode 612              Rotator vs Captain Shrederator
# 7    2021           Episode 613                          Rotator vs Tantrum
# 8    2021                SCSF 3                           Glitch vs Rotator
# 9    2020         Bounty Bronco                           Bronco vs Rotator
# 10   2020         Bounty Bronco                          Rotator vs Axolotl
# 11   2020         Bounty Bronco              Rotator vs Captain Shrederator
# 12   2020         Bounty Bronco                        Rotator vs MaDCaTter
# 13   2020           Episode 503                             Rotator vs Beta
# 14   2020           Episode 506                         Rotator vs Valkyrie
# 15   2020           Episode 508                         Rotator vs Big Dill
# 16   2020           Episode 512                          Jackpot vs Rotator
# 17   2020           Episode 513                         End Game vs Rotator
# 18   2019             Episode 1                         SawBlaze vs Rotator
# 19   2019            Episode 11                       Rotator vs Death Roll
# 20   2019            Episode 14                       Rotator vs Blacksmith
# 21   2019             Episode 4                        Rotator vs Bombshell
# 22   2019             Episode 7                        Tombstone vs Rotator
# 23   2018       Day 1 Session 2                          Rotator vs Petunia
# 24   2018       Day 2 Session 2                         Predator vs Rotator
# 25   2018       Day 4 Session 2                   Warrior Dragon vs Rotator
# 26   2018       Day 6 Session 2                         Skorpios vs Rotator
# 27   2018   Quarter Finals 2018                       Rotator vs Bite Force
# 28   2018         Sweet 16 2018                          Icewave vs Rotator
# 29   2016  Qualifiers Session 1                     Rotator vs Witch Doctor
# 30   2016     Sunday Exhibition  Whiplash vs The Disk o' Inferno vs Rotator
#
#                    Results
# 0        Hydra by KO 1m24s
# 1      Rotator by KO 2m49s
# 2   Bloodsport by KO 1m47s
# 3                      NaN
# 4            Rotator by JD
# 5            Rotator by JD
# 6      Rotator by KO 1m16s
# 7            Tantrum 2m59s
# 8         Glitch by KO 52s
# 9            Rotator by JD
# 10     Rotator by KO 1m19s
# 11           Rotator by JD
# 12      Rotator by KO 2m5s
# 13              Beta by JD
# 14          Valkyrie by JD
# 15     Rotator by KO 2m45s
# 16     Rotator by KO 1m28s
# 17          End Game by JD
# 18       SawBlaze by JD 3m
# 19        Death Roll by JD
# 20        Blacksmith by JD
# 21       Rotator by KO 57s
# 22     Rotator by KO 2m59s
# 23           Petunia by JD
# 24      Rotator by KO 1m7s
# 25           Rotator by JD
# 26           Rotator by JD
# 27  Bite Force by KO 1m19s
# 28           Rotator by JD
# 29  Witch Doctor by KO 42s
# 30           Rotator by JD

# %% [markdown]
# # DataFrame # 2

# %%
robot_dict['rotator-2019']['stats']
# Out:
#                    Stats Career  WCVII  2021   2020   2019  2018  2016
# 0          Total matches     29      3     5      9      5     6     1
# 1         Win percentage    55%    33%   60%    67%    40%   67%    0%
# 2             Total wins     16      1     3      6      2     4     0
# 3                 Losses     13      2     2      3      3     2     1
# 4              Knockouts      9      1     1      4      2     1     0
# 5          KO percentage    31%    33%   20%    44%    40%   17%    0%
# 6  Average knockout time  109 s  169 s  76 s  114 s  118 s  67 s   NaN
# 7      Knockouts against      5      2     1      0      0     1     1
# 8  KO against percentage    17%    67%   20%     0%     0%   17%  100%
# 9   Judges decision wins     11      0     2      6      0     3     0
